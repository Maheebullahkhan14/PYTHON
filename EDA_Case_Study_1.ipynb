# %% [markdown]
# <a href="https://colab.research.google.com/github/Maheebullahkhan14/PYTHON/blob/main/EDA_Case_Study_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Analysis with python **

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Supermart Grocery Sales - Retail Analytics Dataset.csv')

# %%
df.head()
# Out:
#    Order ID Customer Name          Category      Sub Category         City  \
# 0         1        Harish      Oil & Masala           Masalas      Vellore
# 1         2         Sudha         Beverages     Health Drinks  Krishnagiri
# 2         3       Hussain       Food Grains      Atta & Flour   Perambalur
# 3         4       Jackson  Fruits & Veggies  Fresh Vegetables   Dharmapuri
# 4         5       Ridhesh       Food Grains   Organic Staples         Ooty
#
#    Order Date Region  Sales  Discount  Profit       State
# 0  11-08-2017  North   1254      0.12  401.28  Tamil Nadu
# 1  11-08-2017  South    749      0.18  149.80  Tamil Nadu
# 2  06-12-2017   West   2360      0.21  165.20  Tamil Nadu
# 3  10-11-2016  South    896      0.25   89.60  Tamil Nadu
# 4  10-11-2016  South   2355      0.26  918.45  Tamil Nadu

# %%
df.tail()
# Out:
#       Order ID Customer Name           Category  Sub Category         City  \
# 9989      9990        Sudeep  Eggs, Meat & Fish          Eggs      Madurai
# 9990      9991          Alan             Bakery      Biscuits  Kanyakumari
# 9991      9992          Ravi        Food Grains          Rice         Bodi
# 9992      9993          Peer       Oil & Masala        Spices   Pudukottai
# 9993      9994        Ganesh        Food Grains  Atta & Flour  Tirunelveli
#
#       Order Date Region  Sales  Discount  Profit       State
# 9989  12/24/2015   West    945      0.16  359.10  Tamil Nadu
# 9990  07-12-2015   West   1195      0.26   71.70  Tamil Nadu
# 9991  06-06-2017   West   1567      0.16  501.44  Tamil Nadu
# 9992  10/16/2018   West   1659      0.15  597.24  Tamil Nadu
# 9993   4/17/2018   West   1034      0.28  165.44  Tamil Nadu

# %%
#checking the datatype of each column
df.dtypes
# Out:
# Order ID           int64
# Customer Name     object
# Category          object
# Sub Category      object
# City              object
# Order Date        object
# Region            object
# Sales              int64
# Discount         float64
# Profit           float64
# State             object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Order ID         0
# Customer Name    0
# Category         0
# Sub Category     0
# City             0
# Order Date       0
# Region           0
# Sales            0
# Discount         0
# Profit           0
# State            0
# dtype: int64

# %%
#total columns 
len(df.columns)
# Out:
# 11

# %%
#total rows
len(df)
# Out:
# 9994

# %%
df.info
# Out:
# <bound method DataFrame.info of       Order ID Customer Name           Category      Sub Category  \
# 0            1        Harish       Oil & Masala           Masalas
# 1            2         Sudha          Beverages     Health Drinks
# 2            3       Hussain        Food Grains      Atta & Flour
# 3            4       Jackson   Fruits & Veggies  Fresh Vegetables
# 4            5       Ridhesh        Food Grains   Organic Staples
# ...        ...           ...                ...               ...
# 9989      9990        Sudeep  Eggs, Meat & Fish              Eggs
# 9990      9991          Alan             Bakery          Biscuits
# 9991      9992          Ravi        Food Grains              Rice
# 9992      9993          Peer       Oil & Masala            Spices
# 9993      9994        Ganesh        Food Grains      Atta & Flour
#
#              City  Order Date Region  Sales  Discount  Profit       State
# ...

# %%
df.columns
# Out:
# Index(['Order ID', 'Customer Name', 'Category', 'Sub Category', 'City',
#        'Order Date', 'Region', 'Sales', 'Discount', 'Profit', 'State'],
#       dtype='object')

# %%
#highest sales
df['Sales'].max()
# Out:
# 2500

# %%
#lowest sales
df['Sales'].min()
# Out:
# 500

# %%
df['Sales'].mean()
# Out:
# 1496.5961576946167

# %%
#how many orders for eggs
len(df[df['Sub Category']=='Eggs'])
# Out:
# 379

# %%
#data that contains food grains
df[df['Category'].str.contains('Food Grains')]
# Out:
#       Order ID Customer Name     Category     Sub Category         City  \
# 2            3       Hussain  Food Grains     Atta & Flour   Perambalur
# 4            5       Ridhesh  Food Grains  Organic Staples         Ooty
# 5            6        Adavan  Food Grains  Organic Staples   Dharmapuri
# 21          22          Alan  Food Grains    Dals & Pulses        Karur
# 55          56        Muneer  Food Grains     Atta & Flour        Salem
# ...        ...           ...          ...              ...          ...
# 9974      9975        Arvind  Food Grains             Rice  Kanyakumari
# 9980      9981       Willams  Food Grains    Dals & Pulses      Vellore
# 9983      9984          Peer  Food Grains             Rice    Nagercoil
# 9991      9992          Ravi  Food Grains             Rice         Bodi
# 9993      9994        Ganesh  Food Grains     Atta & Flour  Tirunelveli
#
#       Order Date   Region  Sales  Discount  Profit       State
# ...

# %%
#how many orders for category food grains
len(df[df['Category'].str.contains('Food Grains')])
# Out:
# 1398

# %%
#get the details of order_id 9991
df[df['Order ID']==9991]
# Out:
#       Order ID Customer Name Category Sub Category         City  Order Date  \
# 9990      9991          Alan   Bakery     Biscuits  Kanyakumari  07-12-2015
#
#      Region  Sales  Discount  Profit       State
# 9990   West   1195      0.26    71.7  Tamil Nadu

# %%
#get the data where category is bakery and only that records where sales is greater then 1500
df[(df['Category']=='Bakery') & (df['Sales'] >= 1500)]
# Out:
#       Order ID Customer Name Category   Sub Category          City  \
# 9           10      Krithika   Bakery          Cakes       Chennai
# 16          17          Alan   Bakery          Cakes    Dharmapuri
# 44          45        Amrish   Bakery       Biscuits   Krishnagiri
# 88          89        Sheeba   Bakery  Breads & Buns    Perambalur
# 100        101        Adavan   Bakery          Cakes    Coimbatore
# ...        ...           ...      ...            ...           ...
# 9924      9925      Krithika   Bakery          Cakes    Pudukottai
# 9927      9928          Shah   Bakery       Biscuits    Coimbatore
# 9929      9930       Sabeela   Bakery  Breads & Buns        Trichy
# 9949      9950           Anu   Bakery  Breads & Buns  Virudhunagar
# 9986      9987          Peer   Bakery       Biscuits       Vellore
#
#       Order Date   Region  Sales  Discount  Profit       State
# 9     06-09-2015     West   1795      0.27  484.65  Tamil Nadu
# ...
